# %%
#float
edad = 25
print(edad)
print(type(edad))  # type() nos dice qué tipo de dato es
# Out:
# 25
# <class 'int'>

# %%
#string
nombre = 'Ana García' 
ciudad = "Santo Domingo" 
mensaje = "¡Python es genial!" 
print(nombre) 
print(type(nombre))
# Out:
# Ana García
# <class 'str'>

# %%
#bool
esta_lloviendo = True
es_mayor_edad = False 
print(esta_lloviendo) 
print(type(esta_lloviendo))
# Out:
# True
# <class 'bool'>

# %%
nombre = "Ana García" # str
edad = 28 # int 
estatura = 1.68 # float 
es_estudiante = True # bool

# %%
# Mostrar la información 
print("=== MI PERFIL ===")
print("Nombre:", nombre) 
print("Edad:", edad, "años") 
print("Estatura:", estatura, "metros") 
print("¿Es estudiante?", es_estudiante)
# Out:
# === MI PERFIL ===
# Nombre: Ana García
# Edad: 28 años
# Estatura: 1.68 metros
# ¿Es estudiante? True
