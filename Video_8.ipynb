# %%
# Creando variables 
nombre = "Ana García" # Guardamos texto 
edad = 25 # Guardamos un número 
es_estudiante = True # Guardamos verdadero/falso

# %%
# Usando las variables 
print(nombre) # Muestra: Ana García
print(edad) # Muestra: 25
# Out:
# Ana García
# 25

# %%
#nombres correctos de variables
nombre = "Ana" 
edad_usuario = 25 
precio_producto = 19.99 
es_mayor_edad = True

# %%
#buenas practicas de nombre(explicativos)
edad_empleado = 25 
nombre_cliente = "Ana" 
tiene_descuento = True

# %%
# Las variables pueden cambiar.Empezamos con un valor 
contador = 0 
print("Contador inicial:", contador) 
# Cambiamos el valor 
contador = 5
print("Contador actualizado:", contador)
# Out:
# Contador inicial: 0
# Contador actualizado: 5

# %%
 # Podemos usar la variable para cambiar a sí misma 
contador = contador + 1 
print("Contador incrementado:", contador)
# Out:
# Contador incrementado: 6

# %%
# Información de usuario 
usuario_nombre = "Carlos Rodríguez" 
usuario_edad = 30 
usuario_salario = 45000.50 
usuario_activo = True 
print("=== PERFIL DE USUARIO ===") 
print(f"Nombre: {usuario_nombre}") 
print(f"Edad: {usuario_edad} años") 
print(f"Salario: ${usuario_salario}") 
print(f"Estado: {'Activo' if usuario_activo else 'Inactivo'}")
# Out:
# === PERFIL DE USUARIO ===
# Nombre: Carlos Rodríguez
# Edad: 30 años
# Salario: $45000.5
# Estado: Activo
