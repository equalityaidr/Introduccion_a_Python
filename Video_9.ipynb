# %%
#usando el comando input
nombre = input("¿Cuál es tu nombre? ")
print(f"¡Hola {nombre}!")
# Out:
# ¿Cuál es tu nombre?  Ana
# ¡Hola Ana!

# %%
#¡IMPORTANTE! input() siempre devuelve texto
# Esto NO funciona como esperamos 
edad = input("¿Cuántos años tienes? ") 
edad_futuro = edad + 1 # ERROR! No podemos sumar texto + número 
print(type(edad)) # <class 'str'> - ¡es texto!
# Out:
# ¿Cuántos años tienes?  32
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 4
#       1 #¡IMPORTANTE! input() siempre devuelve texto
#       2 # Esto NO funciona como esperamos
#       3 edad = input("¿Cuántos años tienes? ")
# ----> 4 edad_futuro = edad + 1 # ERROR! No podemos sumar texto + número
#       5 print(type(edad))
#
# TypeError: can only concatenate str (not "int") to str

# %%
# Forma correcta 
edad_texto = input("¿Cuántos años tienes? ") 
edad_numero = int(edad_texto) # Convertimos texto a número 
edad_futuro = edad_numero + 1 
print(f"El próximo año tendrás {edad_futuro} años")
 # Forma más directa 
edad = int(input("¿Cuántos años tienes? ")) 
edad_futuro = edad + 1 
print(f"El próximo año tendrás {edad_futuro} años")
# Out:
# ¿Cuántos años tienes?  32
# El próximo año tendrás 33 años
# ¿Cuántos años tienes?  33
# El próximo año tendrás 34 años

# %%
#Programa interactivo
print("=== CALCULADORA DE IMC ===") 
# Recopilar información del usuario
 nombre = input("¿Cuál es tu nombre? ") 
peso = float(input("¿Cuál es tu peso en kg? ")) 
altura = float(input("¿Cuál es tu altura en metros? ")) 
# Calcular IMC 
imc = peso / (altura ** 2) 
# Mostrar resultado personalizado 
print(f"\n¡Hola {nombre}!") 
print(f"Tu IMC es: {imc:.2f}") 
if imc < 18.5: categoria = "bajo peso" 
elif imc < 25: categoria = "peso normal" 
else: categoria = "sobrepeso" 
print(f"Tu categoría es: {categoria}")
