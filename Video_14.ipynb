# %%
# ❌ Malo - No se entiende qué representa
x=True
if x:
    print("Hacer algo")
# Out:
# Hacer algo

# %%
# ✅ Bueno - Queda claro qué verificamos  
usuario_autenticado=True
if usuario_autenticado:
    print("Mostrar panel de control")
# Out:
# Mostrar panel de control

# %%
# ✅ Aún mejor - Nombres que se leen como preguntas
es_mayor_edad=edad>=18
tiene_descuento=es_estudiante or es_adulto_mayor
if es_mayor_edad and tiene_descuento:
    print("Aplicar descuento especial")

# %%
# ❌ Malo - Demasiado anidamiento
def verificar_acceso(usuario, password, intentos):
    if usuarui !="":
        if pasword !="":
            if intentos <3:
                        if usuario == "admin":
                    if password == "123":
                        return "Acceso concedido"
                    else:
                        return "Contraseña incorrecta"
                else:
                    return "Usuario no válido"
            else:
                return "Demasiados intentos"
        else:
            return "Password requerido"
    else:
        return "Usuario requerido"

# %%
# Mejor- Condiciones de salida temprana
def verificar_acceso_limpio(usuario, password, intentos):
    if usuario =="":
        return "Usuario requerido"
    if password == "":
        return "Password requerido"
    if intentos >=3:
        return "Demasiados intentos"
    if usuario != admin:
        return "Usuario no valido"
    if password != "123":
        return "Contrasena incorrecta"
return "Acceso concedido"

# %%
# ❌ Malo - Números "mágicos" sin explicación
if edad >=18:
    descuento=0
elif edad>=65:
    descuento=30
elif edad <12:
    descuento =50

# %%
#Mejor-Constantes con nombres descriptivos
EDAD_MAYOR=18
EDAD_ADULTO_MAYOR=65
EDAD_NIÑO=12
DESCUENTO_ADULTO_MAYOR=30
DESCUENTO_NIÑO=50
DESCUENTO_ADULTO=0

if edad >=EDAD_MAYOR:
    if edad >=EDAD_ADULTO:
        descuento = DESCUENTO_ADULTO_MAYOR
else:
    descuento=DECUSNTO_ADULTO

elif edad<EDAD_NIÑO:
    descuento=DESCUENTO_NIÑO

# %%
#Sistema de calificacion de credito
ingresos=50000
deudas=15000
historial_credito=750
antiguedad_empleo=36 #meses

#Calcular ratio deuda-ingreso
ratio_deuda_ingreso=deudas/ingresos

#Criterios de aprobacion de credito
tiene_ingresos_suficientes = ingresos >= 30000
ratio_deuda_aceptable = ratio_deuda <= 0.4  # Máximo 40% de deudas
buen_historial = historial_credito >= 650
empleo_estable = antiguedad_empleo >= 12  # Mínimo 1 año

# Decisión final de aprobación
credito_aprobado = (tiene_ingresos_suficientes and 
                   ratio_deuda_aceptable and 
                   buen_historial and 
                   empleo_estable)

if credito_aprobado:
    print("✅ Crédito APROBADO")
    # Calcular tasa de interés basada en el score crediticio
    if historial_credito >= 750:
        tasa_interes = 8.5
    elif historial_credito >= 700:
        tasa_interes = 12.0
    else:
        tasa_interes = 15.5
    
    print(f"Tasa de interés ofrecida: {tasa_interes}%")
else:
    print("❌ Crédito DENEGADO")
    # Explicar razones específicas
    print("Razones:")
    if not tiene_ingresos_suficientes:
        print("- Ingresos insuficientes (mínimo $30,000)")
    if not ratio_deuda

#Decision final de aprobacion
